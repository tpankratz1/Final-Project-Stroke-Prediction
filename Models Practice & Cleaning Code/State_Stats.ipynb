# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import and read the Health Rankings data
Start_df = pd.read_csv("Data/All_Data.csv")
Start_df.head()
# Out:
#    FIPS  Num_Per_100k    State   County  Percent_Smokers  Percent_Obese  \
# 0  1001         107.0  Alabama  Autauga             19.0           36.0
# 1  1003          82.5  Alabama  Baldwin             17.0           29.0
# 2  1005          96.1  Alabama  Barbour             22.0           44.0
# 3  1007         112.3  Alabama     Bibb             20.0           38.0
# 4  1009          96.1  Alabama   Blount             20.0           36.0
#
#    Food_Environment_Index  Percent_Access_Exercise  \
# 0                     7.1                     71.0
# 1                     7.9                     69.0
# 2                     5.5                     53.0
# 3                     7.6                     49.0
# 4                     8.5                     32.0
#
#    Primary_Care_Physician_Rate  Mental_Health_Providers_Rate  \
# 0                         45.0                          13.0
# 1                         73.0                          89.0
# ...

# %%
Alabama_df=Start_df.groupby(["State"])

Alabama_df.head()
# Out:
#        FIPS  Num_Per_100k    State    County  Percent_Smokers  Percent_Obese  \
# 0      1001         107.0  Alabama   Autauga             19.0           36.0
# 1      1003          82.5  Alabama   Baldwin             17.0           29.0
# 2      1005          96.1  Alabama   Barbour             22.0           44.0
# 3      1007         112.3  Alabama      Bibb             20.0           38.0
# 4      1009          96.1  Alabama    Blount             20.0           36.0
# ...     ...           ...      ...       ...              ...            ...
# 3119  56001          65.7  Wyoming    Albany             16.0           23.0
# 3120  56003          69.9  Wyoming  Big Horn             16.0           30.0
# 3121  56005          34.9  Wyoming  Campbell             17.0           34.0
# 3122  56007          60.3  Wyoming    Carbon             16.0           28.0
# 3123  56009          67.5  Wyoming  Converse             17.0           30.0
#
# ...

# %%
Smoker_df=Start_df['Percent_Smokers']
Smoker_df.head()
# Out:
# 0    19.0
# 1    17.0
# 2    22.0
# 3    20.0
# 4    20.0
# Name: Percent_Smokers, dtype: float64

# %%
State_df=Start_df.groupby(["State"])

State_df.head()
# Out:
#        FIPS  Num_Per_100k    State    County  Percent_Smokers  Percent_Obese  \
# 0      1001         107.0  Alabama   Autauga             19.0           36.0
# 1      1003          82.5  Alabama   Baldwin             17.0           29.0
# 2      1005          96.1  Alabama   Barbour             22.0           44.0
# 3      1007         112.3  Alabama      Bibb             20.0           38.0
# 4      1009          96.1  Alabama    Blount             20.0           36.0
# ...     ...           ...      ...       ...              ...            ...
# 3119  56001          65.7  Wyoming    Albany             16.0           23.0
# 3120  56003          69.9  Wyoming  Big Horn             16.0           30.0
# 3121  56005          34.9  Wyoming  Campbell             17.0           34.0
# 3122  56007          60.3  Wyoming    Carbon             16.0           28.0
# 3123  56009          67.5  Wyoming  Converse             17.0           30.0
#
# ...

# %%
average_smokers = State_df["Percent_Smokers"].mean()
average_smokers
# Out:
# State
# Alabama                 20.641791
# Alaska                  22.517241
# Arizona                 16.666667
# Arkansas                20.880000
# California              12.517241
# Colorado                14.968750
# Connecticut             12.625000
# Delaware                17.666667
# District of Columbia    17.000000
# Florida                 17.925373
# Georgia                 19.849057
# Hawaii                  13.000000
# Idaho                   15.159091
# Illinois                16.362745
# Indiana                 19.739130
# Iowa                    15.030303
# Kansas                  16.104762
# Kentucky                22.616667
# Louisiana               21.109375
# Maine                   17.500000
# Maryland                14.958333
# Massachusetts           14.642857
# Michigan                18.602410
# Minnesota               15.022989
# Mississippi             20.695122
# Missouri                21.695652
# Montana                 17.267857
# ...

# %%
State_df.count()
# Out:
#                       FIPS  Num_Per_100k  County  Percent_Smokers  \
# State
# Alabama                 67            67      67               67
# Alaska                  29            26      29               29
# Arizona                 15            15      15               15
# Arkansas                75            75      75               75
# California              58            58      58               58
# Colorado                64            64      64               64
# Connecticut              8             8       8                8
# Delaware                 3             3       3                3
# District of Columbia     1             1       1                1
# Florida                 67            67      67               67
# Georgia                159           159     159              159
# Hawaii                   5             5       5                5
# Idaho                   44            44      44               44
# ...

# %%
for col in Start_df.columns:
    print(col)
# Out:
# FIPS
# Num_Per_100k
# State
# County
# Percent_Smokers
# Percent_Obese
# Food_Environment_Index
# Percent_Access_Exercise
# Primary_Care_Physician_Rate
# Mental_Health_Providers_Rate
# Percent_Some_College
# Percent_Unemployed
# Income_Inequality_Ratio
# Violent_Crime_Rate
# Average_Daily_Air_Polution_Particle_Matter
# Percent_Long_Commute_Drives_Alone
# Percent_Rural

# %%
Average_Daily_Air_Polution_Particle_Matter_State = State_df["Average_Daily_Air_Polution_Particle_Matter"].mean()
Average_Daily_Air_Polution_Particle_Matter_State
# Out:
# State
# Alabama                 10.328358
# Alaska                        NaN
# Arizona                  6.693333
# Arkansas                10.049333
# California               8.637931
# Colorado                 5.826562
# Connecticut              8.225000
# Delaware                 9.400000
# District of Columbia    10.900000
# Florida                  7.452239
# Georgia                  9.928302
# Hawaii                        NaN
# Idaho                    7.211364
# Illinois                10.614706
# Indiana                 11.080435
# Iowa                     9.648485
# Kansas                   8.391429
# Kentucky                 9.989167
# Louisiana                9.560937
# Maine                    7.475000
# Maryland                 9.770833
# Massachusetts            8.457143
# Michigan                 8.875904
# Minnesota                9.302299
# Mississippi              9.489024
# Missouri                 9.687826
# Montana                  6.283929
# ...

# %%
Food_Environment_Index_State = State_df["Food_Environment_Index"].mean()
Food_Environment_Index_State
# Out:
# State
# Alabama                 6.726866
# Alaska                  6.134483
# Arizona                 6.073333
# Arkansas                6.277333
# California              7.703448
# Colorado                7.814063
# Connecticut             8.287500
# Delaware                8.233333
# District of Columbia    8.400000
# Florida                 6.958209
# Georgia                 6.975316
# Hawaii                  7.560000
# Idaho                   7.215909
# Illinois                7.996040
# Indiana                 7.978889
# Iowa                    8.189899
# Kansas                  7.525714
# Kentucky                7.470085
# Louisiana               6.728125
# Maine                   7.775000
# Maryland                8.358333
# Massachusetts           8.492857
# Michigan                7.818293
# Minnesota               8.381609
# Mississippi             5.767901
# Missouri                7.216522
# Montana                 6.941071
# Nebraska                7.446237
# ...

# %%
Percent_Unemployed_State = State_df["Percent_Unemployed"].mean()
Percent_Unemployed_State
# Out:
# State
# Alabama                 6.831343
# Alaska                  9.103448
# Arizona                 7.586667
# Arkansas                4.665333
# California              6.874138
# Colorado                3.406250
# Connecticut             4.937500
# Delaware                4.466667
# District of Columbia    6.000000
# Florida                 5.138806
# Georgia                 6.083648
# Hawaii                  3.275000
# Idaho                   4.397727
# Illinois                6.084314
# Indiana                 4.479348
# Iowa                    3.675758
# Kansas                  4.057143
# Kentucky                6.279167
# Louisiana               7.014062
# Maine                   4.343750
# Maryland                4.820833
# Massachusetts           3.978571
# Michigan                5.842169
# Minnesota               4.652874
# Mississippi             6.900000
# Missouri                5.057391
# Montana                 4.367857
# Nebraska                3.140860
# ...

# %%
Income_Inequality_Ratio_State = State_df["Income_Inequality_Ratio"].mean()
Income_Inequality_Ratio_State
# Out:
# State
# Alabama                 5.241791
# Alaska                  4.189655
# Arizona                 4.706667
# Arkansas                4.793333
# California              4.832759
# Colorado                4.290625
# Connecticut             4.725000
# Delaware                4.233333
# District of Columbia    7.200000
# Florida                 4.523881
# Georgia                 4.987421
# Hawaii                  4.475000
# Idaho                   4.125000
# Illinois                4.390196
# Indiana                 3.991304
# Iowa                    4.086869
# Kansas                  4.037143
# Kentucky                4.955000
# Louisiana               5.504688
# Maine                   4.418750
# Maryland                4.316667
# Massachusetts           5.028571
# Michigan                4.213253
# Minnesota               4.104598
# Mississippi             5.248780
# Missouri                4.314783
# Montana                 4.344643
# Nebraska                4.029032
# ...

# %%
average_smokers_state=average_smokers
average_smokers_state
# Out:
# State
# Alabama                 20.641791
# Alaska                  22.517241
# Arizona                 16.666667
# Arkansas                20.880000
# California              12.517241
# Colorado                14.968750
# Connecticut             12.625000
# Delaware                17.666667
# District of Columbia    17.000000
# Florida                 17.925373
# Georgia                 19.849057
# Hawaii                  13.000000
# Idaho                   15.159091
# Illinois                16.362745
# Indiana                 19.739130
# Iowa                    15.030303
# Kansas                  16.104762
# Kentucky                22.616667
# Louisiana               21.109375
# Maine                   17.500000
# Maryland                14.958333
# Massachusetts           14.642857
# Michigan                18.602410
# Minnesota               15.022989
# Mississippi             20.695122
# Missouri                21.695652
# Montana                 17.267857
# ...

# %%
average_smokers_state.describe()
# Out:
# count    51.000000
# mean     17.197884
# std       2.827913
# min       9.758621
# 25%      15.229545
# 50%      16.917293
# 75%      18.664348
# max      22.616667
# Name: Percent_Smokers, dtype: float64

# %%
Income_Inequality_Ratio_State.describe()
# Out:
# count    51.000000
# mean      4.556417
# std       0.524223
# min       3.896552
# 25%       4.226667
# 50%       4.441026
# 75%       4.759167
# max       7.200000
# Name: Income_Inequality_Ratio, dtype: float64

# %%
Percent_Unemployed_State.describe()
# Out:
# count    51.000000
# mean      5.225064
# std       1.289874
# min       2.820000
# 25%       4.432197
# 50%       5.088710
# 75%       5.985075
# max       9.103448
# Name: Percent_Unemployed, dtype: float64

# %%
Average_Daily_Air_Polution_Particle_Matter_State.describe()
# Out:
# count    49.000000
# mean      8.617632
# std       1.433657
# min       5.817647
# 25%       7.475000
# 50%       8.790226
# 75%       9.687826
# max      11.378409
# Name: Average_Daily_Air_Polution_Particle_Matter, dtype: float64

# %%
Food_Environment_Index_State = State_df["Food_Environment_Index"].mean()
Food_Environment_Index_State.describe()
# Out:
# count    51.000000
# mean      7.513175
# std       0.719281
# min       5.767901
# 25%       6.971848
# 50%       7.527660
# 75%       8.168084
# max       8.560000
# Name: Food_Environment_Index, dtype: float64

# %%
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x7ff6cd17dde0>
