# %%
import pandas as pd
import numpy as np

# %%
# Import and read the Health Rankings data
health_rankings_df = pd.read_csv("Data/2018_County_Health_Rankings_US_Data.csv")
health_rankings_df.head()
# Out:
#      FIPS    State   County  Years of Potential Life Lost Rate  95% CI - Low  \
# 0  1001.0  Alabama  Autauga                             9409.0        8492.0
# 1  1003.0  Alabama  Baldwin                             7468.0        7026.0
# 2  1005.0  Alabama  Barbour                             8929.0        7634.0
# 3  1007.0  Alabama     Bibb                            11742.0       10058.0
# 4  1009.0  Alabama   Blount                             9359.0        8463.0
#
#    95% CI - High Quartile  Years of Potential Life Lost Rate (Black)  \
# 0        10326.0        2                                    11806.0
# 1         7909.0        1                                    10336.0
# 2        10225.0        1                                     9141.0
# 3        13426.0        4                                    11297.0
# 4        10255.0        1                                        NaN
#
#    Years of Potential Life Lost Rate (Hispanic)  \
# ...

# %%
# Replace % with Percent in column headings
health_rankings_df = health_rankings_df.rename(columns=lambda s: s. replace("%", "Percent"))
health_rankings_df.head()
# Out:
#      FIPS    State   County  Years of Potential Life Lost Rate  \
# 0  1001.0  Alabama  Autauga                             9409.0
# 1  1003.0  Alabama  Baldwin                             7468.0
# 2  1005.0  Alabama  Barbour                             8929.0
# 3  1007.0  Alabama     Bibb                            11742.0
# 4  1009.0  Alabama   Blount                             9359.0
#
#    95Percent CI - Low  95Percent CI - High Quartile  \
# 0              8492.0              10326.0        2
# 1              7026.0               7909.0        1
# 2              7634.0              10225.0        1
# 3             10058.0              13426.0        4
# 4              8463.0              10255.0        1
#
#    Years of Potential Life Lost Rate (Black)  \
# 0                                    11806.0
# 1                                    10336.0
# 2                                     9141.0
# 3                                    11297.0
# ...

# %%
# Include wanted columns and remove unwanted columns
health_rankings_df = health_rankings_df[["FIPS","State","County","Percent Smokers","Percent Obese","Food Environment Index","Percent With Access","PCP Rate","MHP Rate","Percent Some College","Percent Unemployed","Income Ratio","Violent Crime Rate","Average Daily PM2.5","Percent Long Commute - Drives Alone"]]
health_rankings_df.head()
# Out:
#      FIPS    State   County  Percent Smokers  Percent Obese  \
# 0  1001.0  Alabama  Autauga             19.0           36.0
# 1  1003.0  Alabama  Baldwin             17.0           29.0
# 2  1005.0  Alabama  Barbour             22.0           44.0
# 3  1007.0  Alabama     Bibb             20.0           38.0
# 4  1009.0  Alabama   Blount             20.0           36.0
#
#    Food Environment Index  Percent With Access  PCP Rate  MHP Rate  \
# 0                     7.1                 71.0      45.0      13.0
# 1                     7.9                 69.0      73.0      89.0
# 2                     5.5                 53.0      42.0       8.0
# 3                     7.6                 49.0      53.0       9.0
# 4                     8.5                 32.0      21.0       9.0
#
#    Percent Some College  Percent Unemployed  Income Ratio  Violent Crime Rate  \
# 0                  61.9                 5.3           4.4               266.0
# ...

# %%
# Rename most column headings
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Percent Smokers", "Percent_Smokers"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Percent Obese", "Percent_Obese"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Food Environment Index", "Food_Environment_Index"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Percent With Access", "Percent_Access_Exercise"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("PCP Rate", "Primary_Care_Physician_Rate"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("MHP Rate", "Mental_Health_Providers_Rate"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Percent Some College", "Percent_Some_College"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Percent Unemployed", "Percent_Unemployed"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Income Ratio", "Income_Inequality_Ratio"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Violent Crime Rate", "Violent_Crime_Rate"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Average Daily PM2.5", "Average_Daily_Air_Polution_Particle_Matter"))
health_rankings_df = health_rankings_df.rename(columns=lambda s: s.replace("Percent Long Commute - Drives Alone", "Percent_Long_Commute_Drives_Alone"))
health_rankings_df
# Out:
#          FIPS    State    County  Percent_Smokers  Percent_Obese  \
# 0      1001.0  Alabama   Autauga             19.0           36.0
# 1      1003.0  Alabama   Baldwin             17.0           29.0
# 2      1005.0  Alabama   Barbour             22.0           44.0
# 3      1007.0  Alabama      Bibb             20.0           38.0
# 4      1009.0  Alabama    Blount             20.0           36.0
# ...       ...      ...       ...              ...            ...
# 3138  56039.0  Wyoming     Teton             14.0           13.0
# 3139  56041.0  Wyoming     Uinta             18.0           32.0
# 3140  56043.0  Wyoming  Washakie             16.0           27.0
# 3141  56045.0  Wyoming    Weston             17.0           32.0
# 3142      NaN      NaN       NaN              NaN            NaN
#
#       Food_Environment_Index  Percent_Access_Exercise  \
# 0                        7.1                     71.0
# 1                        7.9                     69.0
# ...

# %%
# Import and read the additional Health Rankings data (Percent Rural)
health_rankings_additional_df = pd.read_csv("Data/2018_County_Health_Rankings_US_Additional_Data.csv")
health_rankings_additional_df.head()
# Out:
#    FIPS    State   County  % Rural
# 0  1001  Alabama  Autauga     42.0
# 1  1003  Alabama  Baldwin     42.3
# 2  1005  Alabama  Barbour     67.8
# 3  1007  Alabama     Bibb     68.4
# 4  1009  Alabama   Blount     90.0

# %%
# Replace % with Percent in column headings
health_rankings_additional_df = health_rankings_additional_df.rename(columns=lambda s: s. replace("% Rural", "Percent_Rural"))
health_rankings_additional_df.head()
# Out:
#    FIPS    State   County  Percent_Rural
# 0  1001  Alabama  Autauga           42.0
# 1  1003  Alabama  Baldwin           42.3
# 2  1005  Alabama  Barbour           67.8
# 3  1007  Alabama     Bibb           68.4
# 4  1009  Alabama   Blount           90.0

# %%
# Remove unwanted columns
health_rankings_additional_df = health_rankings_additional_df[["FIPS","Percent_Rural"]]
health_rankings_additional_df.head()
# Out:
#    FIPS  Percent_Rural
# 0  1001           42.0
# 1  1003           42.3
# 2  1005           67.8
# 3  1007           68.4
# 4  1009           90.0

# %%
health_rankings_additional_df.dtypes
# Out:
# FIPS               int64
# Percent_Rural    float64
# dtype: object

# %%
health_rankings_additional_df.set_index('FIPS')
health_rankings_additional_df
# Out:
#        FIPS  Percent_Rural
# 0      1001           42.0
# 1      1003           42.3
# 2      1005           67.8
# 3      1007           68.4
# 4      1009           90.0
# ...     ...            ...
# 3137  56037           10.9
# 3138  56039           46.4
# 3139  56041           43.1
# 3140  56043           36.0
# 3141  56045           54.5
#
# [3142 rows x 2 columns]

# %%
health_rankings_additional_df.to_csv('Data/Health_Rankings_Additional_Final.csv', index=False)

# %%
# Combine the the two data sets into a single dataset
health_rankings_final_df = pd.merge(health_rankings_additional_df, health_rankings_df, on=["FIPS", "FIPS"])
health_rankings_final_df.head()
# Out:
#    FIPS  Percent_Rural    State   County  Percent_Smokers  Percent_Obese  \
# 0  1001           42.0  Alabama  Autauga             19.0           36.0
# 1  1003           42.3  Alabama  Baldwin             17.0           29.0
# 2  1005           67.8  Alabama  Barbour             22.0           44.0
# 3  1007           68.4  Alabama     Bibb             20.0           38.0
# 4  1009           90.0  Alabama   Blount             20.0           36.0
#
#    Food_Environment_Index  Percent_Access_Exercise  \
# 0                     7.1                     71.0
# 1                     7.9                     69.0
# 2                     5.5                     53.0
# 3                     7.6                     49.0
# 4                     8.5                     32.0
#
#    Primary_Care_Physician_Rate  Mental_Health_Providers_Rate  \
# 0                         45.0                          13.0
# 1                         73.0                          89.0
# ...

# %%
# Move Percent Rural column to the far right
health_rankings_final_df = health_rankings_final_df[["FIPS","State","County","Percent_Smokers","Percent_Obese","Food_Environment_Index","Percent_Access_Exercise","Primary_Care_Physician_Rate","Mental_Health_Providers_Rate","Percent_Some_College","Percent_Unemployed","Income_Inequality_Ratio","Violent_Crime_Rate","Average_Daily_Air_Polution_Particle_Matter","Percent_Long_Commute_Drives_Alone","Percent_Rural"]]
health_rankings_final_df
# Out:
#        FIPS    State      County  Percent_Smokers  Percent_Obese  \
# 0      1001  Alabama     Autauga             19.0           36.0
# 1      1003  Alabama     Baldwin             17.0           29.0
# 2      1005  Alabama     Barbour             22.0           44.0
# 3      1007  Alabama        Bibb             20.0           38.0
# 4      1009  Alabama      Blount             20.0           36.0
# ...     ...      ...         ...              ...            ...
# 3137  56037  Wyoming  Sweetwater             18.0           31.0
# 3138  56039  Wyoming       Teton             14.0           13.0
# 3139  56041  Wyoming       Uinta             18.0           32.0
# 3140  56043  Wyoming    Washakie             16.0           27.0
# 3141  56045  Wyoming      Weston             17.0           32.0
#
#       Food_Environment_Index  Percent_Access_Exercise  \
# 0                        7.1                     71.0
# 1                        7.9                     69.0
# ...

# %%
# Check number of unique values in each column.
health_rankings_final_df.nunique()
# Out:
# FIPS                                          3142
# State                                           51
# County                                        1850
# Percent_Smokers                                 33
# Percent_Obese                                   35
# Food_Environment_Index                          86
# Percent_Access_Exercise                        101
# Primary_Care_Physician_Rate                    175
# Mental_Health_Providers_Rate                   491
# Percent_Some_College                           528
# Percent_Unemployed                             117
# Income_Inequality_Ratio                         55
# Violent_Crime_Rate                             684
# Average_Daily_Air_Polution_Particle_Matter      98
# Percent_Long_Commute_Drives_Alone               70
# Percent_Rural                                  869
# dtype: int64

# %%
health_rankings_final_df.dtypes
# Out:
# FIPS                                            int64
# State                                          object
# County                                         object
# Percent_Smokers                               float64
# Percent_Obese                                 float64
# Food_Environment_Index                        float64
# Percent_Access_Exercise                       float64
# Primary_Care_Physician_Rate                   float64
# Mental_Health_Providers_Rate                  float64
# Percent_Some_College                          float64
# Percent_Unemployed                            float64
# Income_Inequality_Ratio                       float64
# Violent_Crime_Rate                            float64
# Average_Daily_Air_Polution_Particle_Matter    float64
# Percent_Long_Commute_Drives_Alone             float64
# Percent_Rural                                 float64
# dtype: object

# %%
health_rankings_final_df.set_index('FIPS')
health_rankings_final_df
# Out:
#        FIPS    State      County  Percent_Smokers  Percent_Obese  \
# 0      1001  Alabama     Autauga             19.0           36.0
# 1      1003  Alabama     Baldwin             17.0           29.0
# 2      1005  Alabama     Barbour             22.0           44.0
# 3      1007  Alabama        Bibb             20.0           38.0
# 4      1009  Alabama      Blount             20.0           36.0
# ...     ...      ...         ...              ...            ...
# 3137  56037  Wyoming  Sweetwater             18.0           31.0
# 3138  56039  Wyoming       Teton             14.0           13.0
# 3139  56041  Wyoming       Uinta             18.0           32.0
# 3140  56043  Wyoming    Washakie             16.0           27.0
# 3141  56045  Wyoming      Weston             17.0           32.0
#
#       Food_Environment_Index  Percent_Access_Exercise  \
# 0                        7.1                     71.0
# 1                        7.9                     69.0
# ...

# %%
health_rankings_final_df.to_csv('Data/Health_Rankings_Final.csv', index=False)
